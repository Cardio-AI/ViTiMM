# %%
# %load_ext autoreload
# %autoreload 2

# %%
from data import dataloaders

trainloader,valloader,testloader = dataloaders(
    modalities=['lab','cxr','med','ecg']
)
# Out:
# /mnt/ssd/anaconda3/envs/cfm/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /mnt/ssd/git-repos/cardio-foundation-model/submodules/transformers/src/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(

# %%
sample = trainloader.dataset[0]
# Out:
# A male 89 years old patient. CXR findings: None. CXR impressions: Left PICC tip is in theupper SVC. No other interval change. The patient received Dexmedetomidine (Precedex) with a dosis of 113 in 0 hours in 1 prescriptions., Fentanyl with a dosis of 125 in 15 hours in 3 prescriptions., Fentanyl (Concentrate) with a dosis of 2 in 25 hours in 5 prescriptions., Metoprolol with a dosis of 5 in 0 hours in 1 prescriptions., Norepinephrine with a dosis of 5 in 5 hours in 11 prescriptions., Phenylephrine with a dosis of 138 in 43 hours in 14 prescriptions., Propofol with a dosis of 2879 in 44 hours in 20 prescriptions., Vasopressin with a dosis of 9 in 0 hours in 1 prescriptions.

# %%
import numpy as np
import matplotlib.pyplot as plt
fig, axs = plt.subplots(1,4)
axs[0].imshow(np.einsum('chw->hwc',sample['cxr']))
axs[1].imshow(np.einsum('chw->hwc',sample['lab']))
axs[2].imshow(np.einsum('chw->hwc',sample['med']))
axs[3].imshow(np.einsum('chw->hwc',sample['ecg']))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(np.einsum('chw->hwc',sample['med']))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
